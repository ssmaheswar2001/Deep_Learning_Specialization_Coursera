# %% [markdown]
# # Speech Recognition
# ## Speech Recognition Problem
# - We're given an audio clip x, and our job is to automatically find a text transcript y.
# - ![image.png](attachment:image.png)
#
# ## Attention model for speech recognition
# - ![image-2.png](attachment:image-2.png)
#
# ## CTC cost for speech recognition
# - Connenctionist temporal classification
# - We're going to use a neural network structed with equal number of input x's and output y's.
# - ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Trigger Word Detection
# - ![image.png](attachment:image.png)
#
# ## Trigger word detection algorithm
# - We take an audio clip, tyat generates fearures x1,x2,x3,.. that we pass through an RNN. All that remains to be done is to define the target labels Y.
# - So when someone just finished saying the trigger word such as Alexa or hey siri, then in the training sets, we can set the target labels to be 0 for everything before that point and after that to set the target label of 1.
# - One disadvantegs of this is it creates a very imbalanced training set to have a lot more 0s than 1s.
# - ![image-2.png](attachment:image-2.png)
