# %% [markdown]
# # Why ML Strategy
# - When trying to improve a deep learning system, we often have a lot of ideas or things we could try.
# - ![image.png](attachment:image.png)

# %% [markdown]
# # Orthogonalization
# - One of the challenages with building machine learning system is that there's so many things we could try, so many things we could change. Including, for example, so many hyperparameter we could tune.
# - A clear-eyed about what to tune in order to try to achieve one effect. This is a proecss we called orthogonalization.
# - ![image.png](attachment:image.png)
