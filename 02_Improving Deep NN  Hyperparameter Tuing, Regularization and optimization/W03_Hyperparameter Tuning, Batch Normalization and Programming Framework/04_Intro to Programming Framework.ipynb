# %% [markdown]
# # Deep Learning Frameworks
# - ![image.png](attachment:image.png)

# %% [markdown]
# # TensorFlow
# - Let's say that we have some cost function J that we want to minimize. For example.

# %%
import numpy as np
import tensorflow as tf
# Out:
# WARNING:tensorflow:From C:\Users\surya\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
w = tf.Variable(0, dtype = tf.float32)
optimizer = tf.keras.optimizers.Adam(0.1)

def train_step():
    with tf.GradientTape() as tape:
        cost = w **2 - 10*w + 25
        
    trainable_variables = [w]
    grads = tape.gradient(cost, trainable_variables)
    optimizer.apply_gradients(zip(grads, trainable_variables))
        
print(w)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.0>

# %%
train_step()
print(w)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.09999931>

# %%
for i in range(1000):
    train_step()
print(w)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=5.000001>

# %%
w = tf.Variable(0, dtype = tf.float32)
x = np.array([1.0, -10.0, 25.0], dtype=np.float32)
optimizer = tf.keras.optimizers.Adam(0.1)

def training(x, w, optimizer):
    
    def cost_fn():
        return x[0]*w**2 + x[1]*w + x[2]
    for i in range(1000):
        optimizer.minimize(cost_fn, [w])
    return (w)

w = training(x, w, optimizer)
print(w)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=5.000001>

# %% [markdown]
# - The hear of the TensorFlow Program is to compute the cost and then Tensorflow automatically figures out the derivatives and how to minimize the cost.
# - Tensorfloe by implementing the forward propaation, through the computation graph, Tensorflow will automatically figure out all the necessary backward calculations.
# - ![image.png](attachment:image.png)
