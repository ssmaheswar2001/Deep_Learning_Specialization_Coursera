# %% [markdown]
# # What we'll Learn
# 1. Neural Networks and Deep Learning.
# 2. Improving Deep Neural Networks : Hyperparameter tuning, Regularization and Optimization.
# 3. Structuring our Machine Learning Project.
# 4. Convolutional Neural Networks
# 5. Sequenc Models

# %% [markdown]
# # What is a Neural Network?
# - The term Deep Learning, refers to training Neural Networks.
# - The function that we have fit to housing prices using linear regression is a very simple neural network. It is almost the simplest possible neural network.
#     - We have the input to the neural network size of a house (x). It goes into the neuron and then it outputs the price (y). The single neuraon implements the linear function.
#     - All that the neuron does is it inputs the size, computes the linear function, takes a max of zero, and then outputs the estimated price.
#     - ![image.png](attachment:image.png)
# - A larger neuron is formed by taking many of the single neurons and stacking them together.
# - In the example, x is all of these 4 inputs and y is the price we're trying to predict. So by stacking together a few of the single neurons.
#     - ![image-2.png](attachment:image-2.png)
# - Each of the circles are called hidden units in the neural network, that each of them takes its inputs all 4 input features.
# - ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Supervised Learning with Neural Networks
# - In supervised, we have some input x, and we want to learn a function mapping to some ouput y.
# - For, real estate and online advertising will use relativeky standard neural networks.
# - For image applications, we'll often use Convolutional neural networks.
# - For sequence data, for example audio has a temporal component. Audio is represnted as a 1D time series or as a 1D temporal sequence. For sequence data, we often use an Recurrent Neural network.
# - Alphabets or words come one at a time. So language is also most naturally represented as sequence data. So complex versions of RNNs are often used for these applications.
# - Complex applications like autonomous driving, where we have an image,  we might end up with a more custom or complex hybrid neural network architecture
# - ![image-2.png](attachment:image-2.png)
# - ![image-3.png](attachment:image-3.png)
# - Structure data means bascially databases of data. So each of the features has a very well defined meaning.
# - Unstructured data refers to things like audio, images where we might have to recognize what's in the image or text.
# - ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Why is Deep Learning taking off?
# - ![image.png](attachment:image.png)
# - Scales drives deep learning progress
#     1. Data
#     2. Computation
#     3. Algorithm
